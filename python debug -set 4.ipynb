# %%
#1.Identify and fix the syntax error in the following code:


age = 18
if age >= 18:
    print("You are eligible to vote")
# Out:
# You are eligible to vote

# %%
#2.Question:
What error will occur in the following code?

# Function not defined [NameError -  name 'greet_user' is not defined]error
def greet():
    print("Hello, World!")

greet()
# Out:
# Object `code` not found.
# Hello, World!

# %%
#3.Identify the error in this code:

name = "Alice"
age = 25
print(f"My name is  {name} and I am  {age}  years old.")
# Out:
# My name is  Alice and I am  25  years old.

# %%
#4.Question:
#What will happen when you run this code?
try:
    a = 10
    b = 0
    result = a / b
    print(result)
except ZeroDivisionError:
    print("Error: You cannot divide by zero!")

except ValueError:
    print("Error: Please enter valid numbers only.")

finally:
    print("✔ Program executed successfully.")

# ZeroDivisionError  occoured
# Out:
# Error: You cannot divide by zero!
# ✔ Program executed successfully.

# %%
#5.What error will occur in the following code?
#ValueError: invalid literal for int() with base 10: 'xyz'
try:
    num = int("xyz")
    print(num)
except ZeroDivisionError:
    print("Error: You cannot divide by zero!")

except ValueError:
    print("Error: Please enter valid numbers only.")

finally:
    print("✔ Program executed successfully.")
# Out:
# Error: Please enter valid numbers only.
# ✔ Program executed successfully.

# %%
#6.Identify the issue in this code:

data = {"name": "John", "age": 30}
print(data["city"])
#Key not found error occured

# %%
#7.What will happen when you run this code?
num = 1
while num < 5:
    print(num)
# loop will print Infinite time, ie loop will not terminate

# %%
#8.What is wrong with this code?

fruits = ("apple", "banana", "cherry")
print(fruits[3])
#out of index error , 0 to 2 can access, index starts with 0

# %%
#9.What will happen when you run this code?
try:
    text = "hello world"
    text.append("!")
except ZeroDivisionError:
    print("Error: You cannot divide by zero!")

except ValueError:
    print("Error: Please enter valid numbers only.")
except AttributeError:
    print("Error: Invalid attribute use!")

finally:
    print("✔ Program executed successfully.")
#string  doesnot have append method
# Out:
# Error: Invalid attribute use!
# ✔ Program executed successfully.

# %%
#10.What is wrong with the following code?
 #name 'randoms' is not defined error --random is the correct module name
import random
print(random.randint(1, 10))
# Out:
# 8
